# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/mario-png-dataset/dataset/labels/train.cache
# /kaggle/input/mario-png-dataset/dataset/labels/train/mario.txt
# /kaggle/input/mario-png-dataset/dataset/images/train/mario.png
# /kaggle/input/mario-png-dataset/augmented_labels/mario_aug_70.txt
# /kaggle/input/mario-png-dataset/augmented_labels/mario_aug_47.txt
# /kaggle/input/mario-png-dataset/augmented_labels/mario_aug_26.txt
# /kaggle/input/mario-png-dataset/augmented_labels/mario_aug_16.txt
# /kaggle/input/mario-png-dataset/augmented_labels/mario_aug_37.txt
# /kaggle/input/mario-png-dataset/augmented_labels/mario_aug_50.txt
# /kaggle/input/mario-png-dataset/augmented_labels/mario_aug_19.txt
# /kaggle/input/mario-png-dataset/augmented_labels/mario_aug_41.txt
# /kaggle/input/mario-png-dataset/augmented_labels/mario_aug_95.txt
# /kaggle/input/mario-png-dataset/augmented_labels/mario_aug_4.txt
# /kaggle/input/mario-png-dataset/augmented_labels/mario_aug_2.txt
# ...

# %%
# Move data

import shutil


src_path = r"/kaggle/input/mario-png-dataset/"
dst_path = r"/kaggle/working"


# shutil.copy(src_path, dst_path)

from distutils.dir_util import copy_tree
copy_tree(src_path, dst_path)
# Out:
# ['/kaggle/working/dataset/labels/train.cache',
#  '/kaggle/working/dataset/labels/train/mario.txt',
#  '/kaggle/working/dataset/images/train/mario.png',
#  '/kaggle/working/augmented_labels/mario_aug_70.txt',
#  '/kaggle/working/augmented_labels/mario_aug_47.txt',
#  '/kaggle/working/augmented_labels/mario_aug_26.txt',
#  '/kaggle/working/augmented_labels/mario_aug_16.txt',
#  '/kaggle/working/augmented_labels/mario_aug_37.txt',
#  '/kaggle/working/augmented_labels/mario_aug_50.txt',
#  '/kaggle/working/augmented_labels/mario_aug_19.txt',
#  '/kaggle/working/augmented_labels/mario_aug_41.txt',
#  '/kaggle/working/augmented_labels/mario_aug_95.txt',
#  '/kaggle/working/augmented_labels/mario_aug_4.txt',
#  '/kaggle/working/augmented_labels/mario_aug_2.txt',
#  '/kaggle/working/augmented_labels/mario_aug_85.txt',
#  '/kaggle/working/augmented_labels/mario_aug_14.txt',
#  '/kaggle/working/augmented_labels/mario_aug_44.txt',
#  '/kaggle/working/augmented_labels/mario_aug_28.txt',
# ...

# %%
pip install ultralytics pyyaml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.1/899.1 kB 15.0 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yaml
print(yaml.__version__)
# Out:
# 6.0.2

# %%
import yaml

# Example YAML data
yaml_data = """
# train: /kaggle/working/dataset/images/train
# val: /kaggle/working/dataset/images/train  # Gunakan gambar sama jika hanya satu gambar tersedia

train: /kaggle/working/augmented_images
val: /kaggle/working/augmented_images

nc: 1  # Number of classes
names: ['Mario']
"""

# Load YAML data
data = yaml.safe_load(yaml_data)
print("Loaded Data:", data)
# Out:
# Loaded Data: {'train': '/kaggle/working/augmented_images', 'val': '/kaggle/working/augmented_images', 'nc': 1, 'names': ['Mario']}

# %%
# !yolo train data=yaml_data model=yolo11s.pt epochs=100 imgsz=720
